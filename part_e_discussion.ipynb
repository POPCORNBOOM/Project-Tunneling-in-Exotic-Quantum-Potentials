# %% [markdown]
# # Discussion Guide
# Summarize the numerical findings from parts (a)-(d). Fill in concrete numbers/plots from your runs.

# %% [markdown]
# ## 1. Localization and Wavefunction Structure
# - Report table from part (a): n, E, sigma, IPR, P_forbidden, tail prob (|x-mean|>2σ), osc_density.
# - Describe how exotic shapes (cusp/rough/soft) change localization and tail weight as n increases.
# - Note visible tails or irregular oscillations in plots; tie them to potential features.

# %% [markdown]
# ## 2. WKB vs Numerics
# - Compare ln T_WKB slopes vs F and bound-state index.
# - Identify where turning points vanish or merge (failure cases).
# - Record discrepancies between WKB T and TDSE escape.

# %% [markdown]
# ## 3. External Field Effects
# - Describe barrier deformation under tilt; onset of over-the-barrier.
# - Any ultrasoft/singular behavior noted?

# %% [markdown]
# ## 4. TDSE Dynamics
# - Summarize survival/flux curves and fitted escape rates.
# - Note resonances or quasi-bound behavior if observed.

# %% [markdown]
# ## 5. Numerical Challenges
# - Grid size, CAP placement, dt stability, rough potential convergence issues.
# - Mitigations used (larger L, finer N, smaller dt).

# %% [markdown]
# ## 6. Open Questions
# - Long-range vs compact barriers?
# - Additional rough/fractal variants to test?
# - Next steps (curvature corrections, multi-turning-point WKB, time-dependent fields).
